# %% [markdown]
# How to download images from Google Images?
# Step 1
# Go to https://images.google.com and search images you need.
# Ctrl + Shift + J open console where copy following rows of code.
#
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));

# %%
from PIL import Image
import glob
import os
import pytesseract

folder = './image_sample/'
file_types = ['*.jpg', '*.bmp', '*.jpeg', '*.gif', '*.img', '*.png']
file_types.extend([str.upper(x) for x in file_types])

list_of_files = []

for file_type in file_types:
    list_of_files.extend(glob.glob(os.path.join(os.path.abspath(folder), file_type)))
    
for path in list_of_files:
    #if os.path.exists(out_path): continue
    try:
        im = Image.open(path)
        text = pytesseract.image_to_string(im, lang = 'eng')
        print("**"+text)
        
    except Exception as e:
        print('%s %s' % (path, e))


#print(pytesseract.image_to_boxes(Image.open('new.jpg')))
# Out:
# **
# **Kott och Fiskbaren
#
# Vasagatan 42
# 111 20 Stockholm
#
# Terminal Id : 1011735
# Box Id : KEAXEGOOOO00' 6275
#
# Kyitto Nr i 142564
# Dino Nr : 110378
# Servitor : Halil
#
# on 2imarl18 21:47
# Halil
#
# Bond: 12
#
# 1 Carlsberg Export 65. 00
# 1 File Lam 255. 00
# |
#
# Salsa verde 25, 00
#
# 1 Ponmes frites 40, 00
# Tot Kyat toe 385.00
# SEK 385.00
#
# Mons% Total Ketto Hons
# Pe pe 52.00" > 13,00
# (2) a= 285.71 ee
# Tot a ei fl AR e8
#
# 385.00 «< Amex
#
# Ong .Nr35560962-3183
# Kottbaren Vasagatan AB
# Valkommen Ater!
# **World Trade Center Stockholm AB
#
# Klarabergsviadukten 70
# 10724 Stockholm
# Tel. + 46 8 700 45 00
# Org.nr. 556273-0803
#
# Kvittonr. 5806649 2018-03-21 esa leat
# cit OAS sie all aL
# Text Sikes Pris Total
#
# Lunchsmérgaés TA 1,00 68,00
#
# 68,00
#
# SS
#
# Summa SEK 68,00
#
# Total imma SEK 68,00
# Eurocard/VISA SEK 68,00
#
# 12% moms SEK 7,29
#
# Kontrallkod:
# GSHDBUDDJK JKL55HX6PDMWHGY5TPDE 4C
# AQM3SC3CN6Z 7NC5HYFKZS5UMIE
#
# Kontrol leahete
# RIHTT 100520000592
#
# tack fér beséket
# Yyalkomna ater!
# **
# **Oxford PER
# Thornhi |]
#
# Expiry 10:26 28/08/18
#
# Payment 10:51 20/48/18
# Amount £12.08
# UAT No. 155 4786 09
#
# UR Br iso
# **World Trade Center Stockholm AB
# Klarabergsviadukten 70
# 10724 Stockholm
# Tel. + 46 8 700 45 00
# Org.nr. 556273-0803
#
# Kvittonr. 5606833 2018-03-22 11:49:31
#
#
#
# Text eg rig Total
# Lunch fisk 1,00 104,00 104,00
#
# Summa :
#
# Total Summa 104,00
# Eurocard/VISA 104,00
# 12% moms 11,14
#
# Kontrol lkod:
# ROTH2RFTRICBAGWSMQHMTNZ T2TOFL370
#
# XFHYUBQROMLRJKWU30E 4 7O5BMQ
#
# Kontrollenhet:
# RIHTT 100520000592
#
# Tack for besdket
# Yalkonna ater!
# **Express Adult
#
# 9 Period Return
#
# Issued at:
# Boarding Stage:
# » Valid to:
#
# Thornhill P and R
#
# THORNHILL
# HEATHROW
#
# © Expiry:
#
# Beate. 19 Jun 2018
#
# Paiq by Card: FO AKA KKD 34.8
# Content Customer services
#
# for Jurney details and
#
# refunds
# Tue, 20 Var 2018
#
# 1
# **Wonder tree
# Heathrow Airport
# Twa TEW
#
# TAM 4
# Joao 290 Mar 2018 14:18
#
# Table: 98 61/1 ORDER #: 1731
#
# 2 Latte
#
# { Egg Avo F/Bread
# 1 Cappuccino
# ]
#
# 6,10
# 8,75
# 2.70
# 10.25
#
# i HO nH
#
# Tofu Ramen
#
# 20% VAT 1 Net 23,21
# 20% VAT 1 4.64
# 20% VAT 1 Total 27 88
#
# Total £fo7 .eo6
#
# OADER ##: 1731
#
# Thank you for visiting and we
# look forward to seeing you sadn
# Tel; 02089767720
# VAT: 340 377 862
#
# jee charge not an luded
# **ORIGINAL-KVITTO
#
# Devashish Bharti
#
# 15 the ¢ oses
#
# Ox5S 2djp Kidlington
# Great Britain
#
# Gastnamn : Devashish Bharti
# Rumsne +0145
#
# Ankoms 3 20.08118
# Avresa 22 03,18
# Bokningsnr : 411285509
# Notanr : 809447330
#
# Grand Ceritral by Scandic den 22.03.18
#
# Deu ext Saas og
# 20.03.18 Mat & diryckesnota 320.00
# Room# 0145 ; CHECKS
# 0050641
# 22.03.18 American Express ~320,00
#
# 3760142002 XX / RK
#
# Att betala: 0,00
#
#
#
#
#
# Totalt inkl, moms 320,00SEK
# Totalt exkl, moms 272, EK
# Toralt roms 7 7 OK
#
#
#
#
#
# Moms 28% 29,00 SEK( 145.00)
# Moms 122% 18,75 SEKC 175,00)
# Signatur:
#
# Legitimetion: :
# Merchant 13: Credit Card No; 3760142002
#
#
#
# Transaction 1D: 406409108 Credit Card Expiry: XX /X
# Approval Code; 8651809 Capture Method ; Manual
# Approval 4 nount: 320,00 Transaction S4mount: 320.00
#
#
#
# Gand Certral by
# S-111 20 Stockholm, Sweder
#
#
#
# Busdksadress, Kunygsgatan 70
# +90 2512 520 00
#
#
#
# Pax +40 69512 S20 i)
#
#
#
# ft i ES grande eritral @ sc arch ct
# **Y 22MAR18 PONTUS IN THE A STOCKHOLM-ARL £21.38
#
#
#
# DOING BUSINESS AS
# PONTUS IN THE AIR
#
# DESCRIPTION AMOUNT
#
# FOREIGN SPEND A... 240,00 SEK
#
# S-190 45
# SWEDEN NON-STERLING TR... £0.62
# **20 Mar ARLANDA EXPRESS/AUTOMA STOCKHOLM SWE £4716
#
# Amount: £4716 Transaction: ARLANDA EXPRESS/AUTOMA
# Posting Date: 21 March 2018 STOCKHOLM SWE
# Transaction Date: 20 March 2018 Exchange Rate: 11.450382
#
# Ref: MT180800660000010011328
# **Wed 18/04/2018 15:55
#
# DB Devashish Bharti <dbharti@gmail.com>
#
# Fwd: ii. Thanks! Your booking is confirmed at Grand Central by Scandic
# To Devashish Bharti
#
# @ if there are problems with how this message is displayed, click here to view it in a web browser.
# Click here to download pictures. To help protect your privacy, Outlook prevented automatic download of some pictures in this message.
#
#
#
#
#
# "99010,
#
# Your reservation
# Check-in
# Check-out
# Breakfast
#
# Lunch
#
# Dinner
#
# Prepayment
#
# Cancellation cost
#
# €esgfp «
#
# Sergels torg
# Map data ©2018 Google
#
#
#
#
#
# (3) Get the print version
#
# 2 nights, 1 room
#
# Tuesday 20 March 2018 (from 15:00)
# Thursday 22 March 2018 (until 12:00)
# Breakfast is included in the room rate.
# Lunch is not included in the room rate
#
# Dinner is not included in the room rate
#
# You will be charged a prepayment of the total price at any
# time.
#
# From now on: SEK 3,316
#
# Cancel your booking
#
# Low rate - no money back. Changing the dates of your stay is
# not possible.
#
# Single Room without Window SEK 2,960.71
#
# 12 % VAT is included. SEK 355.29
#
# Total price
#
# SEK 3,316
# **Passengers
#
# Devashish Bharti Adult
#
# Price of this trip
#
# London (LHR) - Stockholm (ARN)
#
# Tue 20 Mar 2018
#
# Adult 77.60 GBP
# Stockholm (ARN) - London (LHR)
#
# Thu 22 Mar 2018
#
# Adult 121.10 GBP
#
# Total price 198.70 GBP
#
# Taxes and carrier- 100.70 GBP
# imposed fees
#
# Identification at check-in,
# security control and gate
#
# E-ticket: Booking reference
#
# Payment & contact details
#
# Card used for payment
# MasterCard************3864
#
# The confirmation has been sent to:
# devashish.bharti@converz.co.uk
#
# Contact telephone
# +447917452263
